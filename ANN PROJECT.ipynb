# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('C:\\Users\\MERINA ANGEL\\Downloads\\heart failure.csv')

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
df.shape
# Out:
# (299, 13)

# %%
(203/299)*100
# Out:
# 67.89297658862876

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.describe(percentiles=[0.25,0.50,0.75,0.100]).T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# ...

# %% [markdown]
# # data visualization

# %%
plt.figure(figsize=(15,10))
cmap = sns.diverging_palette(2, 165, s=80, l=55, n=9)
corr= df.corr()
sns.heatmap(corr, cmap=cmap,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df['age'],hue=df['DEATH_EVENT'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(x=df['diabetes'],hue=df['DEATH_EVENT'])
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x=df['high_blood_pressure'],hue=df['DEATH_EVENT'])
# Out:
# <AxesSubplot:xlabel='high_blood_pressure', ylabel='count'>

# %%
# Checking for potential outliers using the "Boxen and Swarm plots" of non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature: 
    plt.figure(figsize=(10,7))
    sns.swarmplot(x=df["DEATH_EVENT"], y=df[i], color="black", alpha=0.7)
    sns.boxenplot(x=df["DEATH_EVENT"], y=df[i])
    plt.show()

# %%
#checking outliers of all independent columns
j=1
plt.figure(figsize=(20,40))
col=df.columns
for i in col:
    plt.subplot(len(col)+1,2,j)
    sns.boxplot(df[i])
    plt.title(i,color='white')
    j=j+1

# %%
#sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
np.percentile(df["creatinine_phosphokinase"],90)
# Out:
# 1203.8

# %%
import statistics

mean=statistics.mean(df['creatinine_phosphokinase'])

# %%
df['creatinine_phosphokinase']=np.where(df['creatinine_phosphokinase']>3000,mean,df['creatinine_phosphokinase'])

# %%
q3, q1 = np.percentile(df, [75 ,25])
iqr = q3 - q1

# %%
uf= q3 + (1.5 * iqr)
lf= q1 - (1.5 * iqr)

# %%
import statistics

mean=statistics.mean(df['platelets'])

# %%
df['platelets']=np.where(df['platelets']>55000,mean,df['platelets'])
df['platelets']=np.where(df['platelets']<5000,mean,df['platelets'])

# %%
import statistics

mean=statistics.mean(df['serum_creatinine'])
mean
# Out:
# 1.3938795986622075

# %%
#serum_creatinine
df['serum_creatinine']=np.where(df['serum_creatinine']>4,mean,df['serum_creatinine'])

# %%
q3, q1 = np.percentile(df['ejection_fraction'], [75 ,25])
iqr = q3 - q1

# %%
uf= q3 + (1.5 * iqr)
lf= q1 - (1.5 * iqr)

# %%
uf
# Out:
# 67.5

# %%
lf
# Out:
# 7.5

# %%
import statistics

mean=statistics.mean(df['ejection_fraction'])

# %%
#serum_creatinine
df['ejection_fraction']=np.where(df['ejection_fraction']>67.5,mean,df['ejection_fraction'])

# %%
q3, q1 = np.percentile(df['serum_sodium'], [75 ,25])
iqr = q3 - q1
uf= q3 + (1.5 * iqr)
lf= q1 - (1.5 * iqr)

# %%
uf
# Out:
# 149.0

# %%
lf
# Out:
# 125.0

# %%
#serum_sodium
df['serum_sodium']=np.where(df['serum_sodium']>125,mean,df['serum_sodium'])

# %%
#checking outliers of all independent columns
j=1
plt.figure(figsize=(20,40))
col=df.columns
for i in col:
    plt.subplot(len(col)+1,2,j)
    sns.boxplot(df[i])
    plt.title(i,color='white')
    j=j+1

# %% [markdown]
# # separating independent and dependent features

# %%
x=df.drop('DEATH_EVENT',axis=1)
y=df['DEATH_EVENT']

# %%
y.value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
from imblearn.combine import SMOTEENN
sme = SMOTEENN(random_state=42)
x_res, y_res = sme.fit_resample(x, y)

# %%
x_res.shape
# Out:
# (234, 12)

# %%
y_res.value_counts()
# Out:
# 1    123
# 0    111
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# # train test split

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_res, y_res,test_size=0.3,random_state=None)

# %% [markdown]
# # feature scaling

# %%
#using standard scaler to standardize the data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
x_train
# Out:
# array([[-1.28704158, -0.74322335,  4.03432532, ..., -1.18197243,
#         -0.61754023,  0.21811842],
#        [ 0.65381662, -0.74322335, -0.33109845, ...,  0.84604342,
#         -0.61754023,  1.20138006],
#        [ 1.1084713 , -0.74322335, -0.63552349, ...,  0.84604342,
#          1.61932771, -1.18482807],
#        ...,
#        [ 1.14136473, -0.74322335,  0.01792096, ...,  0.84604342,
#         -0.61754023,  0.51789331],
#        [-0.17401485, -0.74322335, -0.6869025 , ...,  0.84604342,
#          1.61932771, -0.48935032],
#        [-0.37135364, -0.74322335, -0.24720426, ..., -1.18197243,
#         -0.61754023, -0.74116123]])

# %%
x_train.shape
# Out:
# (163, 12)

# %%
x_test
# Out:
# array([[ 0.23990088, -0.74322335, -0.49998666, -0.83541407, -1.44956303,
#         -0.61754023,  0.        ,  0.12998289,  0.7645753 , -1.18197243,
#         -0.61754023, -1.23279205],
#        [-1.11473803, -0.74322335,  0.37081008, -0.83541407, -1.2106905 ,
#         -0.61754023,  0.        , -0.68774209, -0.13679221,  0.84604342,
#         -0.61754023, -1.18482807],
#        [-1.41576206, -0.74322335,  0.37080874, -0.83541407, -0.45783385,
#         -0.61754023,  0.        , -0.55751844, -0.13679221,  0.84604342,
#         -0.61754023, -0.59726928],
#        [-0.75349688,  1.34549055, -0.25487853,  1.1970112 , -0.13568597,
#         -0.61754023,  0.        ,  2.88030923, -0.13679221,  0.84604342,
#         -0.61754023, -0.05767448],
#        [-0.33958115,  1.34549055, -0.50560196, -0.83541407, -1.01160401,
#         -0.61754023,  0.        , -0.2710328 , -0.13679221,  0.84604342,
#          1.61932771,  0.72174023],
# ...

# %% [markdown]
# # BUILDING MODEL OF ANN

# %%
import tensorflow as tf

# %%
ann=tf.keras.models.Sequential() #initialzing the ann

# %%
from keras import callbacks

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# %%
from tensorflow.keras.layers import Dropout

# %%
ann.add(tf.keras.layers.Dense(units=12,kernel_initializer='uniform',activation='PReLU')) #12 columns
ann.add(Dropout(0.2))
#using dense we can specify how many hidden neurons are needed and drop out of 20% neurons

# %%
ann.add(tf.keras.layers.Dense(units=6,kernel_initializer='uniform',activation='PReLU'))
ann.add(Dropout(0.2))
#using dense we can specify how many hidden neurons are needed and drop out of 50% neurons

# %%
#ann.add(tf.keras.layers.Dense(units=6,kernel_initializer='uniform',activation='PReLU'))
#ann.add(Dropout(0.7))
#using dense we can specify how many hidden neurons are needed and drop out of 50% neurons

# %%
output=ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
#binary  classification

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
model_training=ann.fit(x_train,y_train,validation_split=0.33,batch_size=10,callbacks=early_stopping,epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 24ms/step - loss: 0.6923 - accuracy: 0.5413 - val_loss: 0.6927 - val_accuracy: 0.5185
# Epoch 2/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6899 - accuracy: 0.7064 - val_loss: 0.6903 - val_accuracy: 0.6667
# Epoch 3/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6868 - accuracy: 0.7064 - val_loss: 0.6870 - val_accuracy: 0.7778
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6813 - accuracy: 0.7890 - val_loss: 0.6814 - val_accuracy: 0.8148
# Epoch 5/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6719 - accuracy: 0.8073 - val_loss: 0.6740 - val_accuracy: 0.8148
# Epoch 6/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.8440 - val_loss: 0.6621 - val_accuracy: 0.8704
# Epoch 7/100
# ...

# %%
model_training.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#summmary history for accuracy
plt.plot(model_training.history['accuracy'])
plt.plot(model_training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
#summmary history for loss
plt.plot(model_training.history['loss'])
plt.plot(model_training.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
y_pred=ann.predict(x_test)
y_pred=(y_pred>0.5)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9295774647887324

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        35
#            1       0.94      0.92      0.93        36
#
#     accuracy                           0.93        71
#    macro avg       0.93      0.93      0.93        71
# weighted avg       0.93      0.93      0.93        71

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[33,  3],
#        [ 2, 33]], dtype=int64)

# %%
from sklearn.datasets import make_circles
from numpy import where
from matplotlib import pyplot
# generate circles
X, y = make_circles(n_samples=150, noise=0.1, random_state=1)
# select indices of points with each class label
for i in range(2):
    samples_ix = where(y == i)
pyplot.scatter(X[samples_ix, 1], X[samples_ix, 0], label=str(i))
pyplot.legend()
pyplot.show()
